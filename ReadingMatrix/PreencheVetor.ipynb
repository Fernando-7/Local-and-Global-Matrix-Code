# %%
import csv
import numpy as np #Código de matriz global
    
novo = open('Codigo.csv') # crinado arquivo onde ficara a matriz
cadeia = csv.reader(novo, delimiter=':')
sequencia1=[]
for linha in cadeia:
    if (cadeia.line_num<25999)&(len(linha[5])<=2):
        sequencia1.append(linha[5])
        #print(cadeia.line_num)
        #print(cadeia.line_num)
        #sequencia1.append(teste)
print(sequencia1)
# Out:
# [' J', ' G', ' G', ' G', ' G', ' B', ' C', ' G', ' G', ' G', ' K', ' F', ' B', ' C', ' G', ' L', ' F', ' B', ' B', ' B', ' J', ' B', ' K', ' B', ' B', ' B', ' B', ' C', ' G', ' J', ' K', ' B', ' B', ' B', ' B', ' J', ' B', ' K', ' F', ' K', ' F', ' F', ' B', ' C', ' F', ' K', ' F', ' J', ' B', ' B', ' B', ' B', ' J', ' G', ' B', ' C', ' B', ' B', ' B', ' B', ' B', ' B', ' K', ' B', ' B', ' B', ' B', ' B', ' K', ' F', ' B', ' C', ' B', ' B', ' K', ' B', ' K', ' B', ' K', ' F', ' B', ' B', ' K', ' J', ' J', ' B', ' C', ' B', ' K', ' B', ' B', ' B', ' B', ' B', ' B', ' J', ' G', ' G', ' G', ' G', ' G', ' J', ' J', ' G', ' G', ' B', ' B', ' B', ' C', ' A', ' A', ' A', ' A', ' A', ' A', ' B', ' K', ' B', ' B', ' C', ' A', ' A', ' A', ' G', ' J', ' B', ' K', ' F', ' K', ' M', ' G', ' G', ' G', ' G', ' B', ' K', ' J', ' G', ' B', ' J', ' J', ' K', ' J', ' L', ' F', ' B', ' B', ' J', ' G', ' K', ' F', ' F', ' F', ' F', ' F', ' K', ' F', ' F', ' B', ' C', ' F', ' F', ' F', ' F', ' K', ' F', '
# ...
